# %%
import torch
import torch.nn as nn
import torch.nn.functional as F

from torchsummary import summary

from first_stage import First_stage

# %%
net = First_stage(nclasses=7)
inputs = torch.randn(2, 3, 64, 2048)

# %%
summary(net, inputs)
# Out:
# ...
# Layer (type:depth-idx)                   Output Shape              Param #
# ...
# ├─BasicConv2d: 1-1                       [-1, 64, 64, 2048]        --
# |    └─Conv2d: 2-1                       [-1, 64, 64, 2048]        1,728
# |    └─BatchNorm2d: 2-2                  [-1, 64, 64, 2048]        128
# ├─BasicConv2d: 1-2                       [-1, 64, 64, 2048]        --
# |    └─Conv2d: 2-3                       [-1, 64, 64, 2048]        36,864
# |    └─BatchNorm2d: 2-4                  [-1, 64, 64, 2048]        128
# ├─BasicConv2d: 1-3                       [-1, 128, 64, 2048]       --
# |    └─Conv2d: 2-5                       [-1, 128, 64, 2048]       73,728
# |    └─BatchNorm2d: 2-6                  [-1, 128, 64, 2048]       256
# ├─MaxPool2d: 1-4                         [-1, 128, 32, 1024]       --
# ├─Sequential: 1-5                        [-1, 64, 32, 1024]        --
# |    └─Inception: 2-7                    [-1, 64, 32, 1024]        --
# ...
